# %% [markdown]
# # python basics 퀴즈 3문제

# %% [markdown]
# 1: 리스트 필터링 (for + if/elif/else)
#
# 다음은 여러 회계 계정 코드가 담긴 리스트입니다. for 반복문과 if/elif/else 조건문을 사용하여,
#
# 1000번대 코드(예: 1101)는 '자산'
#
# 2000번대 코드(예: 2101)는 '부채'
#
# 그 외 코드는 '기타' 라고 분류하여 출력하는 코드를 작성해 보세요.

# %%
account_codes = [1101, 5105, 2101, 1205, 3101]
for a,i in enumerate(account_codes):
  if i >= 1000 and i < 2000:
    result = '자산'
  elif i >= 2000 and i < 3000:
    result = '부채'
  else:
    result = '기타'

  print(f"{i}: {result}")
# Out:
# 1101: 자산
# 5105: 기타
# 2101: 부채
# 1205: 자산
# 3101: 기타

# %% [markdown]
# 2: 함수 만들기 (def + list + return)
#
# 거래 금액 리스트(transactions)를 입력받아, "총 거래 건수", "총 거래 금액", "평균 거래 금액"을 반환(return)하는 analyze_transactions라는 이름의 함수를 정의해 보세요.

# %%
transactions = [10000, 50000, 120000, 30000]
def analyze_transactions(data):
  count = len(data)
  total = sum(data)
  average = sum(data) / len(data)
  return count, total, average

count, total, average = analyze_transactions(transactions)
print(f"총 거래 건수: {count}건")
print(f"총 거래 금액: {total}원")
print(f"평균 거래 금액: {average}원")
# Out:
# 총 거래 건수: 4건
# 총 거래 금액: 210000원
# 평균 거래 금액: 52500.0원

# %% [markdown]
# 3: 딕셔너리 반복 (for + dict + f-string)
#
# 직원별 급여 정보가 담긴 딕셔너리(salaries)가 있습니다. for 반복문을 사용해 딕셔너리의 모든 키(key)와 값(value)을 순회하면서, 각 직원의 '예상 상여금'(급여의 15%)을 계산하고, f-string을 이용해 다음과 같이 출력해 보세요.

# %%
salaries = {'sam': 3000, 'sugar': 4500, 'park': 5000}
for name, salary in salaries.items():
  bonus = salary * 0.15
  print(f"{name}의 예상 상여금은 {bonus}원 입니다.")
# Out:
# sam의 예상 상여금은 450.0원 입니다.
# sugar의 예상 상여금은 675.0원 입니다.
# park의 예상 상여금은 750.0원 입니다.
