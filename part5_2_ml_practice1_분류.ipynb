# %% [markdown]
# Load library

# %%
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# Load Data

# %%
breast_cancer = load_breast_cancer()
breast_cancer_df = pd.DataFrame(data=breast_cancer.data, columns=breast_cancer.feature_names)
breast_cancer_df['label'] = breast_cancer.target
breast_cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Step1. 데이터 탐색 및 준비
# - 데이터 구조
# - 데이터 통계정보
# - 분석 유형 확인
# - 결측치 처리
# - 데이터분할

# %%
breast_cancer_df.shape
# Out:
# (569, 31)

# %%
breast_cancer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  label                    569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
breast_cancer_df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst texture  \
# count     569.000000              569.000000  ...     569.000000
# mean        0.181162                0.062798  ...      25.677223
# std         0.027414                0.007060  ...       6.146258
# min         0.106000                0.049960  ...      12.020000
# 25%         0.161900                0.057700  ...      21.080000
# 50%         0.179200                0.061540  ...      25.410000
# 75%         0.195700                0.066120  ...      29.720000
# max         0.304000                0.097440  ...      49.540000
#
#        worst perimeter   worst area  worst smoothness  worst compactness  \
# count       569.000000   569.000000        569.000000         569.000000
# mean        107.261213   880.583128          0.132369           0.254265
# std          33.602542   569.356993          0.022832           0.157336
# min          50.410000   185.200000          0.071170           0.027290
# 25%          84.110000   515.300000          0.116600           0.147200
# 50%          97.660000   686.500000          0.131300           0.211900
# 75%         125.400000  1084.000000          0.146000           0.339100
# max         251.200000  4254.000000          0.222600           1.058000
#
#        worst concavity  worst concave points  worst symmetry  \
# count       569.000000            569.000000      569.000000
# mean          0.272188              0.114606        0.290076
# std           0.208624              0.065732        0.061867
# min           0.000000              0.000000        0.156500
# 25%           0.114500              0.064930        0.250400
# 50%           0.226700              0.099930        0.282200
# 75%           0.382900              0.161400        0.317900
# max           1.252000              0.291000        0.663800
#
#        worst fractal dimension       label
# count               569.000000  569.000000
# mean                  0.083946    0.627417
# std                   0.018061    0.483918
# min                   0.055040    0.000000
# 25%                   0.071460    0.000000
# 50%                   0.080040    1.000000
# 75%                   0.092080    1.000000
# max                   0.207500    1.000000
#
# [8 rows x 31 columns]

# %%
breast_cancer_df['label'].value_counts()
# Out:
# label
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
breast_cancer_df.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
target = breast_cancer_df.pop('label')
from sklearn.model_selection import train_test_split
X_tr, X_test, y_tr, y_test = train_test_split(breast_cancer_df, target, stratify=target, test_size=0.2, random_state = 0)
print(X_tr.shape, X_test.shape, y_tr.shape, y_test.shape)
# Out:
# (455, 30) (114, 30) (455,) (114,)

# %% [markdown]
# Step2. 학습
# - DecisionTreeClassifier
# - KNeighborsClassifier
# - SVC
# - RandomForestClassifier
# - LogisticRegression
# - GradientBoostingClassifier

# %%
# DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state = 0)
dt.fit(X_tr, y_tr)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
# KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
kn = KNeighborsClassifier(n_neighbors= 5)
kn.fit(X_tr, y_tr)
# Out:
# KNeighborsClassifier()

# %%
# SVC
from sklearn.svm import SVC
svc = SVC(random_state=0)
svc.fit(X_tr, y_tr)
# Out:
# SVC(random_state=0)

# %%
# RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state = 0, n_estimators=300)
rf.fit(X_tr, y_tr)
# Out:
# RandomForestClassifier(n_estimators=300, random_state=0)

# %%
# LogisticRegression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0)
lr.fit(X_tr,y_tr)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
# GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
gbm = GradientBoostingClassifier(random_state=0)
gbm.fit(X_tr, y_tr)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
# XGBClassifier
from xgboost import XGBClassifier, plot_importance
import matplotlib.pyplot as plt
xgb = XGBClassifier(random_state = 0, n_estimators=300, learning_rate=0.1, max_depth=3)
xgb.fit(X_tr, y_tr)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
fig, ax = plt.subplots()
plot_importance(xgb, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
# LGBMClassifier
from lightgbm import LGBMClassifier, plot_importance
lgb = LGBMClassifier(random_state=0, n_estimators=300, verbose=-1)
lgb.fit(X_tr, y_tr)
# Out:
# LGBMClassifier(n_estimators=300, random_state=0, verbose=-1)

# %%
fig, ax = plt.subplots()
plot_importance(lgb, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# Step3. 평가지표
# - 혼동행렬
# - 정확도
# - 정밀도
# - 재현율
# - F1_Score
# - AUC

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None):
  confusion = confusion_matrix(y_test, pred)
  accuracy = accuracy_score(y_test, pred)
  precision = precision_score(y_test, pred)
  recall = recall_score(y_test, pred)
  f1 = f1_score(y_test, pred)
  print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
  print('혼동행렬')
  print(confusion)

# %%
model_list = [dt, kn, svc, rf, lr, gbm, xgb, lgb]

for model in model_list:
  pred = model.predict(X_test)
  accuracy = accuracy_score(y_test, pred)
  model_name = model.__class__.__name__
  print('\n{} 성능지표:'.format(model_name))
  get_clf_eval(y_test, pred)
# Out:
# DecisionTreeClassifier 성능지표:
# 정확도: 0.9386, 정밀도: 0.9710, 재현율: 0.9306, F1: 0.9504
# 혼동행렬
# [[40  2]
#  [ 5 67]]
#
# KNeighborsClassifier 성능지표:
# 정확도: 0.9123, 정밀도: 0.9306, 재현율: 0.9306, F1: 0.9306
# 혼동행렬
# [[37  5]
#  [ 5 67]]
#
# SVC 성능지표:
# 정확도: 0.9123, 정밀도: 0.8974, 재현율: 0.9722, F1: 0.9333
# 혼동행렬
# [[34  8]
#  [ 2 70]]
#
# RandomForestClassifier 성능지표:
# 정확도: 0.9474, 정밀도: 0.9714, 재현율: 0.9444, F1: 0.9577
# 혼동행렬
# [[40  2]
#  [ 4 68]]
#
# LogisticRegression 성능지표:
# 정확도: 0.9474, 정밀도: 0.9583, 재현율: 0.9583, F1: 0.9583
# 혼동행렬
# [[39  3]
#  [ 3 69]]
#
# GradientBoostingClassifier 성능지표:
# 정확도: 0.9298, 정밀도: 0.9571, 재현율: 0.9306, F1: 0.9437
# 혼동행렬
# [[39  3]
#  [ 5 67]]
#
# XGBClassifier 성능지표:
# 정확도: 0.9561, 정밀도: 0.9718, 재현율: 0.9583, F1: 0.9650
# 혼동행렬
# [[40  2]
#  [ 3 69]]
#
# LGBMClassifier 성능지표:
# 정확도: 0.9386, 정밀도: 0.9710, 재현율: 0.9306, F1: 0.9504
# 혼동행렬
# [[40  2]
#  [ 5 67]]

# %% [markdown]
# Step4. 성능개선

# %%
# Early stopping - XGBoost

xgb2 = XGBClassifier(n_estimators=300, learning_rate=0.1, max_depth=3, random_state=0,
                     early_stopping_rounds=100)
xgb2.fit(X_tr, y_tr, eval_set=[(X_tr, y_tr)])
xgb_pred = xgb2.predict(X_test)
xgb_accuracy = accuracy_score(y_test, xgb_pred)
print(xgb_accuracy)
# Out:
# [0]	validation_0-logloss:0.57901
# [1]	validation_0-logloss:0.51131
# [2]	validation_0-logloss:0.45422
# [3]	validation_0-logloss:0.40640
# [4]	validation_0-logloss:0.36579
# [5]	validation_0-logloss:0.33024
# [6]	validation_0-logloss:0.29832
# [7]	validation_0-logloss:0.27224
# [8]	validation_0-logloss:0.24794
# [9]	validation_0-logloss:0.22589
# [10]	validation_0-logloss:0.20689
# [11]	validation_0-logloss:0.19087
# [12]	validation_0-logloss:0.17665
# [13]	validation_0-logloss:0.16273
# [14]	validation_0-logloss:0.15014
# [15]	validation_0-logloss:0.13864
# [16]	validation_0-logloss:0.12834
# [17]	validation_0-logloss:0.11889
# [18]	validation_0-logloss:0.11020
# [19]	validation_0-logloss:0.10266
# [20]	validation_0-logloss:0.09556
# [21]	validation_0-logloss:0.08927
# [22]	validation_0-logloss:0.08369
# [23]	validation_0-logloss:0.07851
# [24]	validation_0-logloss:0.07393
# [25]	validation_0-logloss:0.06933
# [26]	validation_0-logloss:0.06530
# [27]	validation_0-logloss:0.06164
# [28]	validation_0-logloss:0.05837
# [29]	validation_0-logloss:0.05543
# [30]	validation_0-logloss:0.05240
# [31]	validation_0-logloss:0.04977
# [32]	validation_0-logloss:0.04726
# [33]	validation_0-logloss:0.04513
# [34]	validation_0-logloss:0.04328
# [35]	validation_0-logloss:0.04142
# [36]	validation_0-logloss:0.03969
# [37]	validation_0-logloss:0.03789
# [38]	validation_0-logloss:0.03643
# [39]	validation_0-logloss:0.03512
# [40]	validation_0-logloss:0.03390
# [41]	validation_0-logloss:0.03268
# [42]	validation_0-logloss:0.03157
# [43]	validation_0-logloss:0.03032
# [44]	validation_0-logloss:0.02933
# [45]	validation_0-logloss:0.02843
# [46]	validation_0-logloss:0.02749
# [47]	validation_0-logloss:0.02668
# [48]	validation_0-logloss:0.02590
# [49]	validation_0-logloss:0.02518
# [50]	validation_0-logloss:0.02442
# [51]	validation_0-logloss:0.02373
# [52]	validation_0-logloss:0.02308
# [53]	validation_0-logloss:0.02241
# [54]	validation_0-logloss:0.02172
# [55]	validation_0-logloss:0.02117
# [56]	validation_0-logloss:0.02056
# [57]	validation_0-logloss:0.02007
# [58]	validation_0-logloss:0.01960
# [59]	validation_0-logloss:0.01905
# [60]	validation_0-logloss:0.01856
# [61]	validation_0-logloss:0.01816
# [62]	validation_0-logloss:0.01777
# [63]	validation_0-logloss:0.01736
# [64]	validation_0-logloss:0.01703
# [65]	validation_0-logloss:0.01661
# [66]	validation_0-logloss:0.01625
# [67]	validation_0-logloss:0.01597
# [68]	validation_0-logloss:0.01558
# [69]	validation_0-logloss:0.01525
# [70]	validation_0-logloss:0.01497
# [71]	validation_0-logloss:0.01463
# [72]	validation_0-logloss:0.01440
# [73]	validation_0-logloss:0.01413
# [74]	validation_0-logloss:0.01391
# [75]	validation_0-logloss:0.01367
# [76]	validation_0-logloss:0.01340
# [77]	validation_0-logloss:0.01319
# [78]	validation_0-logloss:0.01303
# [79]	validation_0-logloss:0.01287
# [80]	validation_0-logloss:0.01268
# [81]	validation_0-logloss:0.01247
# [82]	validation_0-logloss:0.01229
# [83]	validation_0-logloss:0.01206
# [84]	validation_0-logloss:0.01191
# [85]	validation_0-logloss:0.01177
# [86]	validation_0-logloss:0.01167
# [87]	validation_0-logloss:0.01153
# [88]	validation_0-logloss:0.01141
# [89]	validation_0-logloss:0.01132
# [90]	validation_0-logloss:0.01117
# [91]	validation_0-logloss:0.01105
# [92]	validation_0-logloss:0.01096
# [93]	validation_0-logloss:0.01084
# [94]	validation_0-logloss:0.01075
# [95]	validation_0-logloss:0.01063
# [96]	validation_0-logloss:0.01052
# [97]	validation_0-logloss:0.01042
# [98]	validation_0-logloss:0.01035
# [99]	validation_0-logloss:0.01025
# [100]	validation_0-logloss:0.01015
# [101]	validation_0-logloss:0.01008
# [102]	validation_0-logloss:0.01001
# [103]	validation_0-logloss:0.00992
# [104]	validation_0-logloss:0.00985
# [105]	validation_0-logloss:0.00976
# [106]	validation_0-logloss:0.00969
# [107]	validation_0-logloss:0.00961
# [108]	validation_0-logloss:0.00955
# [109]	validation_0-logloss:0.00946
# [110]	validation_0-logloss:0.00940
# [111]	validation_0-logloss:0.00935
# [112]	validation_0-logloss:0.00927
# [113]	validation_0-logloss:0.00921
# [114]	validation_0-logloss:0.00911
# [115]	validation_0-logloss:0.00904
# [116]	validation_0-logloss:0.00898
# [117]	validation_0-logloss:0.00895
# [118]	validation_0-logloss:0.00888
# [119]	validation_0-logloss:0.00880
# [120]	validation_0-logloss:0.00874
# [121]	validation_0-logloss:0.00867
# [122]	validation_0-logloss:0.00862
# [123]	validation_0-logloss:0.00859
# [124]	validation_0-logloss:0.00853
# [125]	validation_0-logloss:0.00845
# [126]	validation_0-logloss:0.00842
# [127]	validation_0-logloss:0.00836
# [128]	validation_0-logloss:0.00832
# [129]	validation_0-logloss:0.00826
# [130]	validation_0-logloss:0.00820
# [131]	validation_0-logloss:0.00818
# [132]	validation_0-logloss:0.00813
# [133]	validation_0-logloss:0.00807
# [134]	validation_0-logloss:0.00805
# [135]	validation_0-logloss:0.00800
# [136]	validation_0-logloss:0.00795
# [137]	validation_0-logloss:0.00791
# [138]	validation_0-logloss:0.00789
# [139]	validation_0-logloss:0.00786
# [140]	validation_0-logloss:0.00782
# [141]	validation_0-logloss:0.00778
# [142]	validation_0-logloss:0.00775
# [143]	validation_0-logloss:0.00773
# [144]	validation_0-logloss:0.00770
# [145]	validation_0-logloss:0.00767
# [146]	validation_0-logloss:0.00765
# [147]	validation_0-logloss:0.00762
# [148]	validation_0-logloss:0.00760
# [149]	validation_0-logloss:0.00755
# [150]	validation_0-logloss:0.00753
# [151]	validation_0-logloss:0.00751
# [152]	validation_0-logloss:0.00748
# [153]	validation_0-logloss:0.00744
# [154]	validation_0-logloss:0.00741
# [155]	validation_0-logloss:0.00739
# [156]	validation_0-logloss:0.00737
# [157]	validation_0-logloss:0.00733
# [158]	validation_0-logloss:0.00731
# [159]	validation_0-logloss:0.00729
# [160]	validation_0-logloss:0.00727
# [161]	validation_0-logloss:0.00726
# [162]	validation_0-logloss:0.00724
# [163]	validation_0-logloss:0.00722
# [164]	validation_0-logloss:0.00720
# [165]	validation_0-logloss:0.00719
# [166]	validation_0-logloss:0.00717
# [167]	validation_0-logloss:0.00715
# [168]	validation_0-logloss:0.00714
# [169]	validation_0-logloss:0.00712
# [170]	validation_0-logloss:0.00710
# [171]	validation_0-logloss:0.00709
# [172]	validation_0-logloss:0.00707
# [173]	validation_0-logloss:0.00705
# [174]	validation_0-logloss:0.00704
# [175]	validation_0-logloss:0.00702
# [176]	validation_0-logloss:0.00701
# [177]	validation_0-logloss:0.00699
# [178]	validation_0-logloss:0.00697
# [179]	validation_0-logloss:0.00696
# [180]	validation_0-logloss:0.00694
# [181]	validation_0-logloss:0.00693
# [182]	validation_0-logloss:0.00691
# [183]	validation_0-logloss:0.00690
# [184]	validation_0-logloss:0.00688
# [185]	validation_0-logloss:0.00687
# [186]	validation_0-logloss:0.00685
# [187]	validation_0-logloss:0.00684
# [188]	validation_0-logloss:0.00682
# [189]	validation_0-logloss:0.00681
# [190]	validation_0-logloss:0.00680
# [191]	validation_0-logloss:0.00678
# [192]	validation_0-logloss:0.00677
# [193]	validation_0-logloss:0.00675
# [194]	validation_0-logloss:0.00674
# [195]	validation_0-logloss:0.00672
# [196]	validation_0-logloss:0.00671
# [197]	validation_0-logloss:0.00670
# [198]	validation_0-logloss:0.00668
# [199]	validation_0-logloss:0.00667
# [200]	validation_0-logloss:0.00666
# [201]	validation_0-logloss:0.00664
# [202]	validation_0-logloss:0.00663
# [203]	validation_0-logloss:0.00662
# [204]	validation_0-logloss:0.00660
# [205]	validation_0-logloss:0.00659
# [206]	validation_0-logloss:0.00658
# [207]	validation_0-logloss:0.00656
# [208]	validation_0-logloss:0.00655
# [209]	validation_0-logloss:0.00654
# [210]	validation_0-logloss:0.00653
# [211]	validation_0-logloss:0.00651
# [212]	validation_0-logloss:0.00650
# [213]	validation_0-logloss:0.00649
# [214]	validation_0-logloss:0.00648
# [215]	validation_0-logloss:0.00646
# [216]	validation_0-logloss:0.00645
# [217]	validation_0-logloss:0.00644
# [218]	validation_0-logloss:0.00643
# [219]	validation_0-logloss:0.00642
# [220]	validation_0-logloss:0.00640
# [221]	validation_0-logloss:0.00639
# [222]	validation_0-logloss:0.00638
# [223]	validation_0-logloss:0.00637
# [224]	validation_0-logloss:0.00636
# [225]	validation_0-logloss:0.00635
# [226]	validation_0-logloss:0.00633
# [227]	validation_0-logloss:0.00632
# [228]	validation_0-logloss:0.00631
# [229]	validation_0-logloss:0.00630
# [230]	validation_0-logloss:0.00629
# [231]	validation_0-logloss:0.00628
# [232]	validation_0-logloss:0.00627
# [233]	validation_0-logloss:0.00626
# [234]	validation_0-logloss:0.00625
# [235]	validation_0-logloss:0.00623
# [236]	validation_0-logloss:0.00622
# [237]	validation_0-logloss:0.00621
# [238]	validation_0-logloss:0.00620
# [239]	validation_0-logloss:0.00619
# [240]	validation_0-logloss:0.00618
# [241]	validation_0-logloss:0.00617
# [242]	validation_0-logloss:0.00616
# [243]	validation_0-logloss:0.00615
# [244]	validation_0-logloss:0.00614
# [245]	validation_0-logloss:0.00613
# [246]	validation_0-logloss:0.00612
# [247]	validation_0-logloss:0.00611
# [248]	validation_0-logloss:0.00610
# [249]	validation_0-logloss:0.00609
# [250]	validation_0-logloss:0.00608
# [251]	validation_0-logloss:0.00607
# [252]	validation_0-logloss:0.00606
# [253]	validation_0-logloss:0.00605
# [254]	validation_0-logloss:0.00604
# [255]	validation_0-logloss:0.00603
# [256]	validation_0-logloss:0.00602
# [257]	validation_0-logloss:0.00601
# [258]	validation_0-logloss:0.00600
# [259]	validation_0-logloss:0.00599
# [260]	validation_0-logloss:0.00599
# [261]	validation_0-logloss:0.00598
# [262]	validation_0-logloss:0.00597
# [263]	validation_0-logloss:0.00596
# [264]	validation_0-logloss:0.00595
# [265]	validation_0-logloss:0.00594
# [266]	validation_0-logloss:0.00593
# [267]	validation_0-logloss:0.00592
# [268]	validation_0-logloss:0.00591
# [269]	validation_0-logloss:0.00590
# [270]	validation_0-logloss:0.00590
# [271]	validation_0-logloss:0.00589
# [272]	validation_0-logloss:0.00588
# [273]	validation_0-logloss:0.00587
# [274]	validation_0-logloss:0.00586
# [275]	validation_0-logloss:0.00585
# [276]	validation_0-logloss:0.00585
# [277]	validation_0-logloss:0.00584
# [278]	validation_0-logloss:0.00583
# [279]	validation_0-logloss:0.00582
# [280]	validation_0-logloss:0.00581
# [281]	validation_0-logloss:0.00581
# [282]	validation_0-logloss:0.00580
# [283]	validation_0-logloss:0.00579
# [284]	validation_0-logloss:0.00578
# [285]	validation_0-logloss:0.00578
# [286]	validation_0-logloss:0.00577
# [287]	validation_0-logloss:0.00576
# [288]	validation_0-logloss:0.00575
# [289]	validation_0-logloss:0.00575
# [290]	validation_0-logloss:0.00574
# [291]	validation_0-logloss:0.00573
# [292]	validation_0-logloss:0.00572
# [293]	validation_0-logloss:0.00572
# [294]	validation_0-logloss:0.00571
# [295]	validation_0-logloss:0.00570
# [296]	validation_0-logloss:0.00570
# [297]	validation_0-logloss:0.00569
# [298]	validation_0-logloss:0.00568
# [299]	validation_0-logloss:0.00568
# 0.956140350877193

# %%
# Early stopping - LGBM

lgb2 = LGBMClassifier(n_estimators=300, learning_rate=0.1, max_depth=3, random_state=0,
                      early_stopping_round=100, verbose=1)
lgb2.fit(X_tr, y_tr, eval_set=[(X_tr, y_tr)])
lgb_pred = lgb2.predict(X_test)
lgb_accuracy = accuracy_score(y_test, lgb_pred)
print(lgb_accuracy)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 285, number of negative: 170
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000314 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4542
# [LightGBM] [Info] Number of data points in the train set: 455, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.626374 -> initscore=0.516691
# [LightGBM] [Info] Start training from score 0.516691
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0.9473684210526315
# /usr/local/lib/python3.12/dist-packages/lightgbm/callback.py:347: UserWarning: Only training set found, disabling early stopping.
#   _log_warning("Only training set found, disabling early stopping.")

# %%
# VotingClassifier
# 개별 모델: LogisticRegression, KNeighborsClassifier 조합
# voting='soft'

from sklearn.ensemble import VotingClassifier
voting_model = VotingClassifier(estimators=[('LR', lr),\
                                            ('KNN', kn)],
                                 voting='soft')
voting_model.fit(X_tr, y_tr)
pred = voting_model.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print('VotingClassifier 정확도: {0:.4f}'.format(accuracy))
# Out:
# VotingClassifier 정확도: 0.9298
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# GridSearchCV - RandomForestClassifier
# - n_estimators : 100, 300, 500
# - max_depth : 6, 8, 10, 12
# - min_samples_leaf : 8, 12, 18
# - min_samples_split : 8, 16, 20

from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators':[100, 300, 500],
    'max_depth' : [6, 8, 10, 12],
    'min_samples_leaf' : [8, 12, 18],
    'min_samples_split' : [8, 16, 20]
}

#RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(X_tr , y_tr)

print('최적 하이퍼 파라미터:\n:', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
# : {'max_depth': 6, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 500}
# 최고 예측 정확도: 0.9428

# %%
# GridSearchCV - GBM
# -n_estimators : 100, 500
# learning_rate : 0.05, 0.1

from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators':[100, 500],
    'learning_rate': [0.05, 0.1]
}

gbm_model = GradientBoostingClassifier(random_state=10)

grid_cv = GridSearchCV(gbm_model, param_grid=params, cv=2, verbose=1)
grid_cv.fit(X_tr, y_tr)
print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# 최적 하이퍼 파라미터:
#  {'learning_rate': 0.05, 'n_estimators': 100}
# 최고 예측 정확도: 0.9450
